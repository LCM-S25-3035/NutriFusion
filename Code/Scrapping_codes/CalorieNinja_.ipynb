# %%
import requests
import pandas as pd
import time
import os
import random

API_KEY = "qxJvuaIfbci1yVQD0YXHXg==RNGyurSoVTcMA4po"
OUTPUT_FILE = "calorieninjas_7000_foods.csv"
DESIRED_COUNT = 7000

# Base food names (you can expand this)
base_foods = [
    "apple", "banana", "orange", "grapes", "mango", "kiwi", "blueberry", "broccoli",
    "carrot", "spinach", "potato", "chicken", "beef", "pork", "bacon", "egg", "milk",
    "cheese", "pizza", "burger", "fries", "cake", "cookie", "ice cream", "salmon",
    "shrimp", "rice", "bread", "yogurt", "tofu", "soup", "chocolate", "smoothie",
    "granola", "tuna", "pasta", "sushi", "burrito", "lentils", "nuts", "avocado",
    "chickpeas", "beans", "honey", "popcorn", "soda", "steak", "mozzarella",
    "lasagna", "cereal", "muffin", "omelet", "sausage", "onion", "garlic", "kale",
    "zucchini", "cauliflower", "peas", "corn", "quinoa", "falafel", "pita", "taco"
]

# Expand queries by adding modifiers
modifiers = [
    "raw", "boiled", "grilled", "fried", "steamed", "roasted", "baked",
    "chopped", "sliced", "1 cup of", "100g of", "cooked", "fresh", "frozen"
]

# Create a large list of unique queries
search_queries = []
for food in base_foods:
    for mod in modifiers:
        search_queries.append(f"{mod} {food}")
random.shuffle(search_queries)

collected_foods = set()
collected_data = []
total_collected = 0

# Setup CSV file if not present
if not os.path.exists(OUTPUT_FILE):
    pd.DataFrame(columns=[
        "name", "calories", "protein_g", "fat_total_g",
        "carbohydrates_total_g", "fiber_g", "sugar_g"
    ]).to_csv(OUTPUT_FILE, index=False)

def fetch_nutrition_data(query):
    url = f"https://api.calorieninjas.com/v1/nutrition?query={query}"
    headers = {"X-Api-Key": API_KEY}
    try:
        response = requests.get(url, headers=headers)
        if response.status_code == 200:
            return response.json().get("items", [])
        else:
            print(f"⚠️ API error {response.status_code}: {response.text}")
    except Exception as e:
        print(f"❌ Request error: {e}")
    return []

# Main scraping loop
for query in search_queries:
    print(f"🔍 Querying: {query}")
    items = fetch_nutrition_data(query)
    if not items:
        continue

    for item in items:
        name = item.get("name")
        if name and name.lower() not in collected_foods:
            collected_foods.add(name.lower())
            total_collected += 1
            collected_data.append({
                "name": name,
                "calories": item.get("calories"),
                "protein_g": item.get("protein_g"),
                "fat_total_g": item.get("fat_total_g"),
                "carbohydrates_total_g": item.get("carbohydrates_total_g"),
                "fiber_g": item.get("fiber_g"),
                "sugar_g": item.get("sugar_g")
            })
            print(f"✅ [{total_collected}] Collected: {name}")

    # Save to CSV every 100 items
    if len(collected_data) >= 100:
        pd.DataFrame(collected_data).to_csv(OUTPUT_FILE, mode='a', header=False, index=False)
        collected_data = []
        print("💾 Saved batch to CSV")

    if total_collected >= DESIRED_COUNT:
        break

    time.sleep(0.5)  # Avoid hitting rate limits

# Final save if needed
if collected_data:
    pd.DataFrame(collected_data).to_csv(OUTPUT_FILE, mode='a', header=False, index=False)

print(f"\n🎉 DONE! Total unique food items collected: {total_collected}")
print(f"📁 File saved to: {os.path.abspath(OUTPUT_FILE)}")
# Out:
# 🔍 Querying: steamed chicken
# ✅ [1] Collected: steamed chicken
# 🔍 Querying: cooked egg
# ✅ [2] Collected: egg
# 🔍 Querying: raw lasagna
# ✅ [3] Collected: lasagna
# 🔍 Querying: 100g of egg
# 🔍 Querying: baked carrot
# ✅ [4] Collected: carrot
# 🔍 Querying: 1 cup of grapes
# ✅ [5] Collected: grapes
# 🔍 Querying: grilled beans
# ✅ [6] Collected: beans
# 🔍 Querying: baked garlic
# ✅ [7] Collected: garlic
# 🔍 Querying: cooked kale
# ✅ [8] Collected: kale
# 🔍 Querying: chopped omelet
# ✅ [9] Collected: omelet
# 🔍 Querying: grilled beef
# ✅ [10] Collected: beef
# 🔍 Querying: grilled mango
# ✅ [11] Collected: mango
# 🔍 Querying: fried falafel
# ✅ [12] Collected: falafel
# 🔍 Querying: 1 cup of egg
# 🔍 Querying: 100g of steak
# ✅ [13] Collected: steak
# 🔍 Querying: baked egg
# 🔍 Querying: grilled cheese
# ✅ [14] Collected: grilled cheese
# 🔍 Querying: raw soup
# ✅ [15] Collected: soup
# 🔍 Querying: roasted spinach
# ✅ [16] Collected: spinach
# 🔍 Querying: boiled tofu
# ✅ [17] Collected: tofu
# 🔍 Querying: frozen falafel
# 🔍 Querying: 100g of pizza
# ✅ [18] Collected: pizza
# 🔍 Querying: steamed nuts
# ✅ [19] Collected: nuts
# 🔍 Querying: steamed lasagna
# 🔍 Querying: grilled quinoa
# ✅ [20] Collected: quinoa
# 🔍 Querying: raw banana
# ✅ [21] Collected: banana
# 🔍 Querying: frozen cereal
# ✅ [22] Collected: cereal
# 🔍 Querying: 100g of tofu
# 🔍 Querying: chopped bread
# ✅ [23] Collected: bread
# 🔍 Querying: raw broccoli
# ✅ [24] Collected: raw broccoli
# 🔍 Querying: sliced burrito
# ✅ [25] Collected: burrito
# 🔍 Querying: cooked pasta
# ✅ [26] Collected: cooked pasta
# 🔍 Querying: baked soup
# 🔍 Querying: 1 cup of lasagna
# 🔍 Querying: raw mozzarella
# ✅ [27] Collected: mozzarella
# 🔍 Querying: sliced beef
# 🔍 Querying: 1 cup of burger
# ✅ [28] Collected: burger
# 🔍 Querying: fresh garlic
# 🔍 Querying: sliced bacon
# ✅ [29] Collected: bacon
# 🔍 Querying: frozen egg
# 🔍 Querying: fried orange
# ✅ [30] Collected: orange
# 🔍 Querying: 100g of soup
# 🔍 Querying: 1 cup of yogurt
# ✅ [31] Collected: yogurt
# 🔍 Querying: raw bread
# 🔍 Querying: grilled honey
# ✅ [32] Collected: honey
# 🔍 Querying: sliced mozzarella
# ✅ [33] Collected: sliced mozzarella
# 🔍 Querying: steamed zucchini
# ✅ [34] Collected: zucchini
# 🔍 Querying: boiled apple
# ✅ [35] Collected: apple
# 🔍 Querying: cooked banana
# 🔍 Querying: frozen nuts
# 🔍 Querying: 100g of carrot
# 🔍 Querying: boiled chickpeas
# ✅ [36] Collected: chickpeas
# 🔍 Querying: boiled nuts
# 🔍 Querying: grilled cereal
# 🔍 Querying: fried sausage
# ✅ [37] Collected: sausage
# 🔍 Querying: fresh cake
# ✅ [38] Collected: cake
# 🔍 Querying: sliced soup
# 🔍 Querying: grilled shrimp
# ✅ [39] Collected: shrimp
# 🔍 Querying: grilled burrito
# 🔍 Querying: fried bacon
# 🔍 Querying: roasted pasta
# ✅ [40] Collected: pasta
# 🔍 Querying: raw cake
# 🔍 Querying: boiled popcorn
# ✅ [41] Collected: popcorn
# 🔍 Querying: cooked beef
# 🔍 Querying: steamed lentils
# ✅ [42] Collected: lentils
# 🔍 Querying: grilled avocado
# ✅ [43] Collected: avocado
# 🔍 Querying: fried soda
# ✅ [44] Collected: soda
# 🔍 Querying: raw fries
# ✅ [45] Collected: fries
# 🔍 Querying: fresh onion
# ✅ [46] Collected: onion
# 🔍 Querying: sliced muffin
# ✅ [47] Collected: muffin
# 🔍 Querying: raw beans
# 🔍 Querying: chopped blueberry
# ✅ [48] Collected: blueberry
# 🔍 Querying: 1 cup of carrot
# 🔍 Querying: frozen tofu
# 🔍 Querying: steamed pasta
# 🔍 Querying: chopped ice cream
# ✅ [49] Collected: ice cream
# 🔍 Querying: frozen muffin
# 🔍 Querying: boiled banana
# 🔍 Querying: fried tofu
# ✅ [50] Collected: fried tofu
# 🔍 Querying: fresh cookie
# ✅ [51] Collected: cookie
# 🔍 Querying: chopped mozzarella
# 🔍 Querying: 100g of lasagna
# 🔍 Querying: fresh orange
# 🔍 Querying: boiled onion
# 🔍 Querying: 1 cup of omelet
# 🔍 Querying: boiled honey
# 🔍 Querying: grilled bacon
# 🔍 Querying: roasted soup
# 🔍 Querying: steamed beef
# 🔍 Querying: sliced tofu
# 🔍 Querying: fried beans
# 🔍 Querying: sliced quinoa
# 🔍 Querying: fresh smoothie
# ✅ [52] Collected: smoothie
# 🔍 Querying: grilled omelet
# 🔍 Querying: roasted popcorn
# 🔍 Querying: boiled broccoli
# ✅ [53] Collected: broccoli
# 🔍 Querying: boiled avocado
# 🔍 Querying: 1 cup of burrito
# 🔍 Querying: sliced pork
# ✅ [54] Collected: pork
# 🔍 Querying: steamed spinach
# ✅ [55] Collected: steamed spinach
# 🔍 Querying: cooked peas
# ✅ [56] Collected: peas
# 🔍 Querying: grilled rice
# ✅ [57] Collected: rice
# 🔍 Querying: 1 cup of taco
# ✅ [58] Collected: taco
# 🔍 Querying: cooked milk
# ✅ [59] Collected: milk
# 🔍 Querying: baked salmon
# ✅ [60] Collected: baked salmon
# 🔍 Querying: roasted kiwi
# ✅ [61] Collected: kiwi
# 🔍 Querying: 100g of bread
# 🔍 Querying: frozen steak
# 🔍 Querying: frozen taco
# 🔍 Querying: chopped lasagna
# 🔍 Querying: 1 cup of chocolate
# ✅ [62] Collected: chocolate
# 🔍 Querying: 1 cup of cheese
# ✅ [63] Collected: cheese
# 🔍 Querying: cooked quinoa
# ✅ [64] Collected: cooked quinoa
# 🔍 Querying: fried soup
# 🔍 Querying: baked taco
# 🔍 Querying: boiled chicken
# ✅ [65] Collected: chicken
# 🔍 Querying: sliced cereal
# 🔍 Querying: boiled yogurt
# 🔍 Querying: boiled beef
# 🔍 Querying: boiled garlic
# 🔍 Querying: fried mozzarella
# ✅ [66] Collected: fried mozzarella
# 🔍 Querying: 100g of broccoli
# 🔍 Querying: cooked chocolate
# 🔍 Querying: frozen mango
# ✅ [67] Collected: frozen mango
# 🔍 Querying: fresh kiwi
# 🔍 Querying: roasted chicken
# ✅ [68] Collected: roasted chicken
# 🔍 Querying: raw corn
# ✅ [69] Collected: corn
# 🔍 Querying: chopped zucchini
# 🔍 Querying: fresh cereal
# 🔍 Querying: baked spinach
# 🔍 Querying: steamed ice cream
# 🔍 Querying: boiled grapes
# 🔍 Querying: 100g of cookie
# 🔍 Querying: 1 cup of pasta
# 🔍 Querying: steamed milk
# 🔍 Querying: chopped banana
# 🔍 Querying: fresh chickpeas
# 🔍 Querying: frozen potato
# ✅ [70] Collected: potato
# 🔍 Querying: frozen milk
# 🔍 Querying: 1 cup of cereal
# 🔍 Querying: cooked chicken
# ✅ [71] Collected: cooked chicken
# 🔍 Querying: 100g of rice
# 🔍 Querying: fried steak
# ✅ [72] Collected: fried steak
# 🔍 Querying: fried omelet
# 🔍 Querying: cooked burrito
# 🔍 Querying: sliced omelet
# 🔍 Querying: chopped steak
# 🔍 Querying: cooked beans
# 🔍 Querying: frozen kale
# 🔍 Querying: sliced granola
# ✅ [73] Collected: granola
# 🔍 Querying: baked grapes
# 🔍 Querying: frozen corn
# 🔍 Querying: steamed smoothie
# 🔍 Querying: boiled pasta
# 🔍 Querying: grilled spinach
# 🔍 Querying: chopped pasta
# 🔍 Querying: 100g of sushi
# ✅ [74] Collected: sushi
# 🔍 Querying: sliced pita
# ✅ [75] Collected: pita
# 🔍 Querying: baked cereal
# 🔍 Querying: 100g of beef
# 🔍 Querying: baked nuts
# 🔍 Querying: chopped salmon
# ✅ [76] Collected: salmon
# 🔍 Querying: 1 cup of spinach
# 🔍 Querying: 1 cup of beans
# 🔍 Querying: 100g of burger
# 🔍 Querying: steamed yogurt
# 🔍 Querying: steamed kale
# 🔍 Querying: boiled chocolate
# 🔍 Querying: cooked salmon
# 🔍 Querying: fresh soda
# 🔍 Querying: 100g of apple
# 🔍 Querying: boiled cauliflower
# ✅ [77] Collected: cauliflower
# 🔍 Querying: cooked garlic
# 🔍 Querying: fresh broccoli
# 🔍 Querying: 100g of cheese
# 🔍 Querying: grilled nuts
# 🔍 Querying: steamed orange
# 🔍 Querying: cooked honey
# 🔍 Querying: 100g of shrimp
# 🔍 Querying: chopped cereal
# 🔍 Querying: 1 cup of blueberry
# 🔍 Querying: cooked burger
# 🔍 Querying: sliced steak
# 🔍 Querying: chopped beans
# 🔍 Querying: fresh pasta
# ✅ [78] Collected: fresh pasta
# 🔍 Querying: frozen chickpeas
# 🔍 Querying: grilled kiwi
# 🔍 Querying: cooked grapes
# 🔍 Querying: steamed burger
# 🔍 Querying: chopped nuts
# 🔍 Querying: roasted nuts
# 🔍 Querying: raw rice
# ✅ [79] Collected: raw rice
# 🔍 Querying: frozen grapes
# 🔍 Querying: boiled kiwi
# 🔍 Querying: roasted grapes
# 🔍 Querying: grilled salmon
# ✅ [80] Collected: grilled salmon
# 🔍 Querying: fried milk
# 🔍 Querying: baked chickpeas
# 🔍 Querying: steamed corn
# 🔍 Querying: steamed apple
# 🔍 Querying: fried honey
# 🔍 Querying: roasted cake
# 🔍 Querying: raw muffin
# 🔍 Querying: steamed beans
# 🔍 Querying: chopped mango
# 🔍 Querying: raw carrot
# 🔍 Querying: grilled kale
# 🔍 Querying: baked avocado
# 🔍 Querying: chopped muffin
# 🔍 Querying: chopped granola
# 🔍 Querying: 1 cup of nuts
# 🔍 Querying: grilled garlic
# 🔍 Querying: fresh pork
# 🔍 Querying: chopped soup
# 🔍 Querying: frozen ice cream
# 🔍 Querying: frozen yogurt
# ✅ [125] Collected: frozen yogurt
# 🔍 Querying: 100g of grapes
# 🔍 Querying: fresh taco
# 🔍 Querying: cooked lentils
# ✅ [126] Collected: cooked lentils
# 🔍 Querying: sliced cake
# 🔍 Querying: grilled popcorn
# 🔍 Querying: 1 cup of kale
# 🔍 Querying: 1 cup of sushi
# 🔍 Querying: cooked muffin
# 🔍 Querying: cooked bacon
# 🔍 Querying: baked sushi
# 🔍 Querying: raw spinach
# 🔍 Querying: fried potato
# ✅ [127] Collected: fried potato
# 🔍 Querying: baked popcorn
# 🔍 Querying: fresh yogurt
# 🔍 Querying: fried salmon
# 🔍 Querying: grilled pork
# 🔍 Querying: cooked fries
# 🔍 Querying: sliced egg
# 🔍 Querying: baked bread
# 🔍 Querying: frozen apple
# 🔍 Querying: boiled salmon
# 🔍 Querying: frozen chocolate
# 🔍 Querying: cooked pizza
# 🔍 Querying: boiled zucchini
# 🔍 Querying: 100g of beans
# 🔍 Querying: roasted orange
# 🔍 Querying: frozen cheese
# 🔍 Querying: grilled yogurt
# 🔍 Querying: fresh ice cream
# 🔍 Querying: raw milk
# 🔍 Querying: baked lasagna
# 🔍 Querying: fried granola
# 🔍 Querying: sliced fries
# 🔍 Querying: boiled soda
# 🔍 Querying: grilled granola
# 🔍 Querying: cooked soda
# 🔍 Querying: steamed cake
# 🔍 Querying: raw granola
# 🔍 Querying: fried ice cream
# ✅ [128] Collected: fried ice cream
# 🔍 Querying: raw apple
# 🔍 Querying: fresh beef
# 🔍 Querying: boiled pita
# 🔍 Querying: fresh spinach
# ✅ [129] Collected: fresh spinach
# 🔍 Querying: 100g of granola
# 🔍 Querying: baked corn
# 🔍 Querying: grilled egg
# 🔍 Querying: chopped chocolate
# 🔍 Querying: roasted muffin
# 🔍 Querying: 100g of orange
# 🔍 Querying: roasted beef
# 🔍 Querying: grilled mozzarella
# 🔍 Querying: frozen beans
# 🔍 Querying: baked milk
# 🔍 Querying: 100g of muffin
# 🔍 Querying: raw honey
# 🔍 Querying: fried corn
# 🔍 Querying: baked pasta
# 🔍 Querying: fresh lasagna
# 🔍 Querying: steamed salmon
# 🔍 Querying: 1 cup of popcorn
# 🔍 Querying: raw chicken
# 🔍 Querying: frozen cookie
# 🔍 Querying: fried spinach
# 🔍 Querying: chopped falafel
# 🔍 Querying: steamed avocado
# 🔍 Querying: 1 cup of sausage
# 🔍 Querying: sliced cheese
# ✅ [130] Collected: sliced cheese
# 🔍 Querying: fried grapes
# 🔍 Querying: grilled tuna
# 🔍 Querying: frozen smoothie
# 🔍 Querying: steamed broccoli
# 🔍 Querying: roasted steak
# 🔍 Querying: chopped corn
# 🔍 Querying: boiled tuna
# 🔍 Querying: grilled soup
# 🔍 Querying: baked zucchini
# 🔍 Querying: raw shrimp
# ✅ [131] Collected: raw shrimp
# 🔍 Querying: raw tuna
# 🔍 Querying: chopped pork
# 🔍 Querying: sliced salmon
# 🔍 Querying: fried rice
# ✅ [132] Collected: fried rice
# 🔍 Querying: cooked chickpeas
# 🔍 Querying: cooked cookie
# 🔍 Querying: chopped spinach
# 🔍 Querying: baked fries
# 🔍 Querying: 100g of yogurt
# 🔍 Querying: fried zucchini
# ✅ [133] Collected: fried zucchini
# 🔍 Querying: steamed kiwi
# 🔍 Querying: steamed soup
# 🔍 Querying: chopped fries
# 🔍 Querying: sliced cookie
# 🔍 Querying: roasted garlic
# 🔍 Querying: fresh banana
# 🔍 Querying: sliced peas
# 🔍 Querying: roasted apple
# 🔍 Querying: boiled mango
# 🔍 Querying: 100g of taco
# 🔍 Querying: frozen soda
# 🔍 Querying: baked pizza
# 🔍 Querying: cooked bread
# 🔍 Querying: 100g of quinoa
# 🔍 Querying: fresh salmon
# 🔍 Querying: steamed mozzarella
# 🔍 Querying: boiled spinach
# ✅ [134] Collected: boiled spinach
# 🔍 Querying: 100g of chickpeas
# 🔍 Querying: frozen cauliflower
# 🔍 Querying: roasted mango
# 🔍 Querying: 1 cup of shrimp
# 🔍 Querying: 1 cup of cookie
# 🔍 Querying: fresh carrot
# 🔍 Querying: roasted chocolate
# 🔍 Querying: frozen mozzarella
# 🔍 Querying: grilled banana
# 🔍 Querying: baked ice cream
# 🔍 Querying: chopped egg
# 🔍 Querying: fried mango
# 🔍 Querying: raw kale
# 🔍 Querying: raw cereal
# 🔍 Querying: fried onion
# ✅ [135] Collected: fried onion
# 🔍 Querying: sliced corn
# 🔍 Querying: fried avocado
# 🔍 Querying: frozen sushi
# 🔍 Querying: baked lentils
# 🔍 Querying: raw potato
# 🔍 Querying: fresh granola
# 🔍 Querying: 1 cup of tofu
# 🔍 Querying: fresh mango
# ✅ [136] Collected: fresh mango
# 🔍 Querying: raw cookie
# 🔍 Querying: 100g of pork
# 🔍 Querying: baked muffin
# 🔍 Querying: baked cookie
# ✅ [137] Collected: baked cookie
# 🔍 Querying: raw egg
# ✅ [138] Collected: raw egg
# 🔍 Querying: fresh burrito
# 🔍 Querying: sliced chickpeas
# 🔍 Querying: chopped cookie
# 🔍 Querying: raw ice cream
# 🔍 Querying: 1 cup of peas
# 🔍 Querying: 1 cup of salmon
# 🔍 Querying: 100g of peas
# 🔍 Querying: raw smoothie
# 🔍 Querying: grilled chickpeas
# 🔍 Querying: chopped chickpeas
# 🔍 Querying: cooked granola
# 🔍 Querying: chopped avocado
# 🔍 Querying: roasted soda
# 🔍 Querying: fried burger
# 🔍 Querying: roasted zucchini
# 🔍 Querying: raw popcorn
# 🔍 Querying: steamed falafel
# 🔍 Querying: boiled falafel
# 🔍 Querying: raw cauliflower
# 🔍 Querying: grilled lentils
# 🔍 Querying: 1 cup of quinoa
# 🔍 Querying: cooked taco
# 🔍 Querying: boiled egg
# ✅ [139] Collected: boiled egg
# 🔍 Querying: baked apple
# ✅ [140] Collected: baked apple
# 🔍 Querying: raw salmon
# ✅ [141] Collected: raw salmon
# 🔍 Querying: 100g of cereal
# 🔍 Querying: roasted salmon
# 🔍 Querying: sliced pasta
# 🔍 Querying: chopped cheese
# 🔍 Querying: roasted rice
# 🔍 Querying: grilled pita
#
# 🎉 DONE! Total unique food items collected: 141
# 📁 File saved to: /content/calorieninjas_7000_foods.csv
