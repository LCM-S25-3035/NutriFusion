# %%
# Initial prompt - for the project nutrifusion, I need to scrap 3 types of datasets. At first I need to scrap recipe and nutrients from edamam.
# Final prompt - In the given code give as much as possible search terms so that i can scrap maximum amount of data

# %%
pip install requests pandas
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.4.26)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import requests
import pandas as pd
import time

# === Your Edamam API credentials here ===
APP_ID = '59456ca4'
APP_KEY = 'ebeb4beaff17d1a14fcec62a904206a3'

# === Extended Search Terms to maximize the data scraping ===
SEARCH_TERMS = [
    # Ingredients
    'chicken', 'chicken breast', 'chicken thighs', 'ground chicken', 'roast chicken', 'grilled chicken', 'chicken soup', 'chicken wings',
    'beef', 'ground beef', 'beef stew', 'roast beef', 'beef tacos', 'beef stir fry',
    'salmon', 'grilled salmon', 'baked salmon', 'salmon fillets', 'salmon steak', 'salmon sushi',
    'tofu', 'fried tofu', 'tofu stir fry', 'tofu scramble', 'tofu curry',
    'mushrooms', 'portobello mushrooms', 'shiitake mushrooms', 'mushroom soup',
    'lentils', 'red lentils', 'green lentils', 'lentil stew', 'lentil curry',
    'shrimp', 'shrimp stir fry', 'shrimp tacos', 'shrimp pasta', 'shrimp soup',
    'avocado', 'avocado toast', 'avocado salad', 'avocado smoothie', 'guacamole',
    'quinoa', 'quinoa salad', 'quinoa stir fry', 'quinoa bowl', 'quinoa soup',

    # Cuisines
    'italian', 'italian pasta', 'italian pizza', 'italian soups', 'italian lasagna', 'italian meatballs',
    'mexican', 'mexican tacos', 'mexican burritos', 'mexican chili', 'mexican enchiladas',
    'indian', 'indian curry', 'indian rice', 'indian lentils', 'indian naan', 'indian biryani',
    'thai', 'thai curry', 'thai noodles', 'thai salad', 'pad thai',
    'french', 'french soup', 'french baguette', 'french cuisine', 'french toast',
    'japanese', 'sushi', 'ramen', 'sushi rolls', 'teriyaki chicken',
    'mediterranean', 'mediterranean salad', 'mediterranean diet', 'mediterranean hummus',
    'korean', 'korean bbq', 'kimchi', 'korean noodles', 'korean soup',

    # Diets
    'vegan', 'vegan soup', 'vegan curry', 'vegan salad', 'vegan dessert',
    'vegetarian', 'vegetarian pizza', 'vegetarian pasta', 'vegetarian stew', 'vegetarian lasagna',
    'gluten free', 'gluten free pizza', 'gluten free pasta', 'gluten free bread',
    'keto', 'keto dinner', 'keto salad', 'keto chicken', 'keto snacks',
    'paleo', 'paleo soup', 'paleo diet', 'paleo salad',
    'low carb', 'low carb dinner', 'low carb salad', 'low carb pizza',
    'dairy free', 'dairy free salad', 'dairy free cheese', 'dairy free cake',

    # Meal Types
    'breakfast', 'breakfast bowl', 'breakfast smoothie', 'breakfast burrito',
    'lunch', 'lunch salad', 'lunch bowl', 'lunch sandwiches',
    'dinner', 'dinner casserole', 'dinner salad', 'dinner pizza',
    'snack', 'snack bars', 'snack bites', 'snack dips',
    'dessert', 'dessert cake', 'dessert cookies', 'dessert pudding',
    'appetizer', 'appetizer salads', 'appetizer dips', 'appetizer recipes',
    'side dish', 'side salad', 'side vegetables', 'side casserole',

    # Dish Types
    'pasta', 'pasta salad', 'pasta dishes', 'pasta soup',
    'pizza', 'pizza dough', 'pizza toppings', 'pizza recipes',
    'soup', 'soup recipes', 'chicken soup', 'vegetable soup',
    'salad', 'green salad', 'fruit salad', 'pasta salad',
    'curry', 'vegetable curry', 'chicken curry', 'beef curry',
    'stir fry', 'chicken stir fry', 'vegetable stir fry', 'shrimp stir fry',
    'sandwich', 'vegan sandwich', 'chicken sandwich', 'vegetarian sandwich'
]

# Settings
TOTAL_RECIPES_TARGET = 8000  # You can change this based on how many recipes you want
RECIPES_PER_TERM = TOTAL_RECIPES_TARGET // len(SEARCH_TERMS)
RECIPES_PER_REQUEST = 100
BASE_URL = 'https://api.edamam.com/api/recipes/v2'

# Function to fetch recipes for a given query
def fetch_recipes(query, total_recipes):
    all_recipes = []
    next_url = f"{BASE_URL}?type=public&q={query}&app_id={APP_ID}&app_key={APP_KEY}&random=true"

    fetched = 0
    request_count = 0
    requests_needed = (total_recipes + RECIPES_PER_REQUEST - 1) // RECIPES_PER_REQUEST

    while fetched < total_recipes:
        if request_count >= requests_needed:
            break

        # Making the API request
        response = requests.get(next_url)
        if response.status_code != 200:
            print(f"Error for '{query}': {response.status_code}")
            break

        data = response.json()
        hits = data.get('hits', [])
        if not hits:
            break

        # Extracting recipe data
        for hit in hits:
            recipe = hit['recipe']
            all_recipes.append({
                'title': recipe.get('label', ''),
                'ingredients': '; '.join(recipe.get('ingredientLines', [])),
                'calories': recipe['totalNutrients'].get('ENERC_KCAL', {}).get('quantity', 0),
                'fat': recipe['totalNutrients'].get('FAT', {}).get('quantity', 0),
                'protein': recipe['totalNutrients'].get('PROCNT', {}).get('quantity', 0),
                'carbs': recipe['totalNutrients'].get('CHOCDF', {}).get('quantity', 0),
                'url': recipe.get('url', ''),
                'servings': recipe.get('yield', 1)
            })
            fetched += 1
            if fetched >= total_recipes:
                break

        # Handling pagination if there's more data
        next_link = data.get('_links', {}).get('next', {}).get('href')
        if not next_link:
            break
        next_url = next_link

        request_count += 1
        # Respect rate limits: wait for 6 seconds between requests
        time.sleep(6)

    print(f"Fetched {fetched} recipes for '{query}'")
    return all_recipes

# Function to save recipes to CSV
def save_to_csv(recipes, filename):
    df = pd.DataFrame(recipes)
    df.to_csv(filename, index=False)
    print(f"Saved {len(df)} recipes to {filename}")

# Main execution
if __name__ == "__main__":
    for term in SEARCH_TERMS:
        print(f"\n--- Starting '{term}' ---")
        # Fetch recipes for each search term
        data = fetch_recipes(term, RECIPES_PER_TERM)
        # Save recipes to CSV
        save_to_csv(data, f"{term.replace(' ', '_')}_recipes.csv")

    print("\nAll scraping tasks completed!")
# Out:
# --- Starting 'chicken' ---
# Fetched 20 recipes for 'chicken'
# Saved 20 recipes to chicken_recipes.csv
#
# --- Starting 'chicken breast' ---
# Fetched 20 recipes for 'chicken breast'
# Saved 20 recipes to chicken_breast_recipes.csv
#
# --- Starting 'chicken thighs' ---
# Error for 'chicken thighs': 429
# Fetched 0 recipes for 'chicken thighs'
# Saved 0 recipes to chicken_thighs_recipes.csv
#
# --- Starting 'ground chicken' ---
# Fetched 20 recipes for 'ground chicken'
# Saved 20 recipes to ground_chicken_recipes.csv
#
# --- Starting 'roast chicken' ---
# Error for 'roast chicken': 429
# Fetched 0 recipes for 'roast chicken'
# Saved 0 recipes to roast_chicken_recipes.csv
#
# --- Starting 'grilled chicken' ---
# Fetched 20 recipes for 'grilled chicken'
# Saved 20 recipes to grilled_chicken_recipes.csv
#
# --- Starting 'chicken soup' ---
# Error for 'chicken soup': 429
# Fetched 0 recipes for 'chicken soup'
# Saved 0 recipes to chicken_soup_recipes.csv
#
# --- Starting 'chicken wings' ---
# Fetched 20 recipes for 'chicken wings'
# Saved 20 recipes to chicken_wings_recipes.csv
#
# --- Starting 'beef' ---
# Error for 'beef': 429
# Fetched 0 recipes for 'beef'
# Saved 0 recipes to beef_recipes.csv
#
# --- Starting 'ground beef' ---
# Fetched 20 recipes for 'ground beef'
# Saved 20 recipes to ground_beef_recipes.csv
#
# --- Starting 'beef stew' ---
# Error for 'beef stew': 429
# Fetched 0 recipes for 'beef stew'
# Saved 0 recipes to beef_stew_recipes.csv
#
# --- Starting 'roast beef' ---
# Fetched 20 recipes for 'roast beef'
# Saved 20 recipes to roast_beef_recipes.csv
#
# --- Starting 'beef tacos' ---
# Error for 'beef tacos': 429
# Fetched 0 recipes for 'beef tacos'
# Saved 0 recipes to beef_tacos_recipes.csv
#
# --- Starting 'beef stir fry' ---
# Fetched 20 recipes for 'beef stir fry'
# Saved 20 recipes to beef_stir_fry_recipes.csv
#
# --- Starting 'salmon' ---
# Error for 'salmon': 429
# Fetched 0 recipes for 'salmon'
# Saved 0 recipes to salmon_recipes.csv
#
# --- Starting 'grilled salmon' ---
# Fetched 20 recipes for 'grilled salmon'
# Saved 20 recipes to grilled_salmon_recipes.csv
#
# --- Starting 'baked salmon' ---
# Error for 'baked salmon': 429
# Fetched 0 recipes for 'baked salmon'
# Saved 0 recipes to baked_salmon_recipes.csv
#
# --- Starting 'salmon fillets' ---
# Fetched 20 recipes for 'salmon fillets'
# Saved 20 recipes to salmon_fillets_recipes.csv
#
# --- Starting 'salmon steak' ---
# Error for 'salmon steak': 429
# Fetched 0 recipes for 'salmon steak'
# Saved 0 recipes to salmon_steak_recipes.csv
#
# --- Starting 'salmon sushi' ---
# Error for 'salmon sushi': 429
# Fetched 0 recipes for 'salmon sushi'
# Saved 0 recipes to salmon_sushi_recipes.csv
#
# --- Starting 'tofu' ---
# Fetched 20 recipes for 'tofu'
# Saved 20 recipes to tofu_recipes.csv
#
# --- Starting 'fried tofu' ---
# Error for 'fried tofu': 429
# Fetched 0 recipes for 'fried tofu'
# Saved 0 recipes to fried_tofu_recipes.csv
#
# --- Starting 'tofu stir fry' ---
# Fetched 20 recipes for 'tofu stir fry'
# Saved 20 recipes to tofu_stir_fry_recipes.csv
#
# --- Starting 'tofu scramble' ---
# Error for 'tofu scramble': 429
# Fetched 0 recipes for 'tofu scramble'
# Saved 0 recipes to tofu_scramble_recipes.csv
#
# --- Starting 'tofu curry' ---
# Fetched 20 recipes for 'tofu curry'
# Saved 20 recipes to tofu_curry_recipes.csv
#
# --- Starting 'mushrooms' ---
# Error for 'mushrooms': 429
# Fetched 0 recipes for 'mushrooms'
# Saved 0 recipes to mushrooms_recipes.csv
#
# --- Starting 'portobello mushrooms' ---
# Fetched 20 recipes for 'portobello mushrooms'
# Saved 20 recipes to portobello_mushrooms_recipes.csv
#
# --- Starting 'shiitake mushrooms' ---
# Error for 'shiitake mushrooms': 429
# Fetched 0 recipes for 'shiitake mushrooms'
# Saved 0 recipes to shiitake_mushrooms_recipes.csv
#
# --- Starting 'mushroom soup' ---
# Fetched 20 recipes for 'mushroom soup'
# Saved 20 recipes to mushroom_soup_recipes.csv
#
# --- Starting 'lentils' ---
# Error for 'lentils': 429
# Fetched 0 recipes for 'lentils'
# Saved 0 recipes to lentils_recipes.csv
#
# --- Starting 'red lentils' ---
# Fetched 20 recipes for 'red lentils'
# Saved 20 recipes to red_lentils_recipes.csv
#
# --- Starting 'green lentils' ---
# Error for 'green lentils': 429
# Fetched 0 recipes for 'green lentils'
# Saved 0 recipes to green_lentils_recipes.csv
#
# --- Starting 'lentil stew' ---
# Fetched 20 recipes for 'lentil stew'
# Saved 20 recipes to lentil_stew_recipes.csv
#
# --- Starting 'lentil curry' ---
# Error for 'lentil curry': 429
# Fetched 0 recipes for 'lentil curry'
# Saved 0 recipes to lentil_curry_recipes.csv
#
# --- Starting 'shrimp' ---
# Fetched 20 recipes for 'shrimp'
# Saved 20 recipes to shrimp_recipes.csv
#
# --- Starting 'shrimp stir fry' ---
# Error for 'shrimp stir fry': 429
# Fetched 0 recipes for 'shrimp stir fry'
# Saved 0 recipes to shrimp_stir_fry_recipes.csv
#
# --- Starting 'shrimp tacos' ---
# Fetched 20 recipes for 'shrimp tacos'
# Saved 20 recipes to shrimp_tacos_recipes.csv
#
# --- Starting 'shrimp pasta' ---
# Error for 'shrimp pasta': 429
# Fetched 0 recipes for 'shrimp pasta'
# Saved 0 recipes to shrimp_pasta_recipes.csv
#
# --- Starting 'shrimp soup' ---
# Fetched 20 recipes for 'shrimp soup'
# Saved 20 recipes to shrimp_soup_recipes.csv
#
# --- Starting 'avocado' ---
# Error for 'avocado': 429
# Fetched 0 recipes for 'avocado'
# Saved 0 recipes to avocado_recipes.csv
#
# --- Starting 'avocado toast' ---
# Fetched 20 recipes for 'avocado toast'
# Saved 20 recipes to avocado_toast_recipes.csv
#
# --- Starting 'avocado salad' ---
# Error for 'avocado salad': 429
# Fetched 0 recipes for 'avocado salad'
# Saved 0 recipes to avocado_salad_recipes.csv
#
# --- Starting 'avocado smoothie' ---
# Fetched 20 recipes for 'avocado smoothie'
# Saved 20 recipes to avocado_smoothie_recipes.csv
#
# --- Starting 'guacamole' ---
# Error for 'guacamole': 429
# Fetched 0 recipes for 'guacamole'
# Saved 0 recipes to guacamole_recipes.csv
#
# --- Starting 'quinoa' ---
# Fetched 20 recipes for 'quinoa'
# Saved 20 recipes to quinoa_recipes.csv
#
# --- Starting 'quinoa salad' ---
# Error for 'quinoa salad': 429
# Fetched 0 recipes for 'quinoa salad'
# Saved 0 recipes to quinoa_salad_recipes.csv
#
# --- Starting 'quinoa stir fry' ---
# Fetched 20 recipes for 'quinoa stir fry'
# Saved 20 recipes to quinoa_stir_fry_recipes.csv
#
# --- Starting 'quinoa bowl' ---
# Error for 'quinoa bowl': 429
# Fetched 0 recipes for 'quinoa bowl'
# Saved 0 recipes to quinoa_bowl_recipes.csv
#
# --- Starting 'quinoa soup' ---
# Fetched 20 recipes for 'quinoa soup'
# Saved 20 recipes to quinoa_soup_recipes.csv
#
# --- Starting 'italian' ---
# Error for 'italian': 429
# Fetched 0 recipes for 'italian'
# Saved 0 recipes to italian_recipes.csv
#
# --- Starting 'italian pasta' ---
# Fetched 20 recipes for 'italian pasta'
# Saved 20 recipes to italian_pasta_recipes.csv
#
# --- Starting 'italian pizza' ---
# Error for 'italian pizza': 429
# Fetched 0 recipes for 'italian pizza'
# Saved 0 recipes to italian_pizza_recipes.csv
#
# --- Starting 'italian soups' ---
# Fetched 20 recipes for 'italian soups'
# Saved 20 recipes to italian_soups_recipes.csv
#
# --- Starting 'italian lasagna' ---
# Error for 'italian lasagna': 429
# Fetched 0 recipes for 'italian lasagna'
# Saved 0 recipes to italian_lasagna_recipes.csv
#
# --- Starting 'italian meatballs' ---
# Fetched 20 recipes for 'italian meatballs'
# Saved 20 recipes to italian_meatballs_recipes.csv
#
# --- Starting 'mexican' ---
# Error for 'mexican': 429
# Fetched 0 recipes for 'mexican'
# Saved 0 recipes to mexican_recipes.csv
#
# --- Starting 'mexican tacos' ---
# Fetched 20 recipes for 'mexican tacos'
# Saved 20 recipes to mexican_tacos_recipes.csv
#
# --- Starting 'mexican burritos' ---
# Error for 'mexican burritos': 429
# Fetched 0 recipes for 'mexican burritos'
# Saved 0 recipes to mexican_burritos_recipes.csv
#
# --- Starting 'mexican chili' ---
# Fetched 20 recipes for 'mexican chili'
# Saved 20 recipes to mexican_chili_recipes.csv
#
# --- Starting 'mexican enchiladas' ---
# Error for 'mexican enchiladas': 429
# Fetched 0 recipes for 'mexican enchiladas'
# Saved 0 recipes to mexican_enchiladas_recipes.csv
#
# --- Starting 'indian' ---
# Fetched 20 recipes for 'indian'
# Saved 20 recipes to indian_recipes.csv
#
# --- Starting 'indian curry' ---
# Error for 'indian curry': 429
# Fetched 0 recipes for 'indian curry'
# Saved 0 recipes to indian_curry_recipes.csv
#
# --- Starting 'indian rice' ---
# Fetched 20 recipes for 'indian rice'
# Saved 20 recipes to indian_rice_recipes.csv
#
# --- Starting 'indian lentils' ---
# Error for 'indian lentils': 429
# Fetched 0 recipes for 'indian lentils'
# Saved 0 recipes to indian_lentils_recipes.csv
#
# --- Starting 'indian naan' ---
# Fetched 20 recipes for 'indian naan'
# Saved 20 recipes to indian_naan_recipes.csv
#
# --- Starting 'indian biryani' ---
# Error for 'indian biryani': 429
# Fetched 0 recipes for 'indian biryani'
# Saved 0 recipes to indian_biryani_recipes.csv
#
# --- Starting 'thai' ---
# Error for 'thai': 429
# Fetched 0 recipes for 'thai'
# Saved 0 recipes to thai_recipes.csv
#
# --- Starting 'thai curry' ---
# Fetched 20 recipes for 'thai curry'
# Saved 20 recipes to thai_curry_recipes.csv
#
# --- Starting 'thai noodles' ---
# Error for 'thai noodles': 429
# Fetched 0 recipes for 'thai noodles'
# Saved 0 recipes to thai_noodles_recipes.csv
#
# --- Starting 'thai salad' ---
# Fetched 20 recipes for 'thai salad'
# Saved 20 recipes to thai_salad_recipes.csv
#
# --- Starting 'pad thai' ---
# Error for 'pad thai': 429
# Fetched 0 recipes for 'pad thai'
# Saved 0 recipes to pad_thai_recipes.csv
#
# --- Starting 'french' ---
# Fetched 20 recipes for 'french'
# Saved 20 recipes to french_recipes.csv
#
# --- Starting 'french soup' ---
# Fetched 20 recipes for 'french soup'
# Saved 20 recipes to french_soup_recipes.csv
#
# --- Starting 'french baguette' ---
# Error for 'french baguette': 429
# Fetched 0 recipes for 'french baguette'
# Saved 0 recipes to french_baguette_recipes.csv
#
# --- Starting 'french cuisine' ---
# Fetched 20 recipes for 'french cuisine'
# Saved 20 recipes to french_cuisine_recipes.csv
#
# --- Starting 'french toast' ---
# Error for 'french toast': 429
# Fetched 0 recipes for 'french toast'
# Saved 0 recipes to french_toast_recipes.csv
#
# --- Starting 'japanese' ---
# Fetched 20 recipes for 'japanese'
# Saved 20 recipes to japanese_recipes.csv
#
# --- Starting 'sushi' ---
# Error for 'sushi': 429
# Fetched 0 recipes for 'sushi'
# Saved 0 recipes to sushi_recipes.csv
#
# --- Starting 'ramen' ---
# Fetched 20 recipes for 'ramen'
# Saved 20 recipes to ramen_recipes.csv
#
# --- Starting 'sushi rolls' ---
# Error for 'sushi rolls': 429
# Fetched 0 recipes for 'sushi rolls'
# Saved 0 recipes to sushi_rolls_recipes.csv
#
# --- Starting 'teriyaki chicken' ---
# Fetched 20 recipes for 'teriyaki chicken'
# Saved 20 recipes to teriyaki_chicken_recipes.csv
#
# --- Starting 'mediterranean' ---
# Error for 'mediterranean': 429
# Fetched 0 recipes for 'mediterranean'
# Saved 0 recipes to mediterranean_recipes.csv
#
# --- Starting 'mediterranean salad' ---
# Fetched 20 recipes for 'mediterranean salad'
# Saved 20 recipes to mediterranean_salad_recipes.csv
#
# --- Starting 'mediterranean diet' ---
# Error for 'mediterranean diet': 429
# Fetched 0 recipes for 'mediterranean diet'
# Saved 0 recipes to mediterranean_diet_recipes.csv
#
# --- Starting 'mediterranean hummus' ---
# Fetched 20 recipes for 'mediterranean hummus'
# Saved 20 recipes to mediterranean_hummus_recipes.csv
#
# --- Starting 'korean' ---
# Error for 'korean': 429
# Fetched 0 recipes for 'korean'
# Saved 0 recipes to korean_recipes.csv
#
# --- Starting 'korean bbq' ---
# Fetched 20 recipes for 'korean bbq'
# Saved 20 recipes to korean_bbq_recipes.csv
#
# --- Starting 'kimchi' ---
# Error for 'kimchi': 429
# Fetched 0 recipes for 'kimchi'
# Saved 0 recipes to kimchi_recipes.csv
#
# --- Starting 'korean noodles' ---
# Fetched 20 recipes for 'korean noodles'
# Saved 20 recipes to korean_noodles_recipes.csv
#
# --- Starting 'korean soup' ---
# Error for 'korean soup': 429
# Fetched 0 recipes for 'korean soup'
# Saved 0 recipes to korean_soup_recipes.csv
#
# --- Starting 'vegan' ---
# Fetched 20 recipes for 'vegan'
# Saved 20 recipes to vegan_recipes.csv
#
# --- Starting 'vegan soup' ---
# Error for 'vegan soup': 429
# Fetched 0 recipes for 'vegan soup'
# Saved 0 recipes to vegan_soup_recipes.csv
#
# --- Starting 'vegan curry' ---
# Fetched 20 recipes for 'vegan curry'
# Saved 20 recipes to vegan_curry_recipes.csv
#
# --- Starting 'vegan salad' ---
# Error for 'vegan salad': 429
# Fetched 0 recipes for 'vegan salad'
# Saved 0 recipes to vegan_salad_recipes.csv
#
# --- Starting 'vegan dessert' ---
# Error for 'vegan dessert': 429
# Fetched 0 recipes for 'vegan dessert'
# Saved 0 recipes to vegan_dessert_recipes.csv
#
# --- Starting 'vegetarian' ---
# Fetched 20 recipes for 'vegetarian'
# Saved 20 recipes to vegetarian_recipes.csv
#
# --- Starting 'vegetarian pizza' ---
# Error for 'vegetarian pizza': 429
# Fetched 0 recipes for 'vegetarian pizza'
# Saved 0 recipes to vegetarian_pizza_recipes.csv
#
# --- Starting 'vegetarian pasta' ---
# Fetched 20 recipes for 'vegetarian pasta'
# Saved 20 recipes to vegetarian_pasta_recipes.csv
#
# --- Starting 'vegetarian stew' ---
# Fetched 20 recipes for 'vegetarian stew'
# Saved 20 recipes to vegetarian_stew_recipes.csv
#
# --- Starting 'vegetarian lasagna' ---
# Error for 'vegetarian lasagna': 429
# Fetched 0 recipes for 'vegetarian lasagna'
# Saved 0 recipes to vegetarian_lasagna_recipes.csv
#
# --- Starting 'gluten free' ---
# Error for 'gluten free': 429
# Fetched 0 recipes for 'gluten free'
# Saved 0 recipes to gluten_free_recipes.csv
#
# --- Starting 'gluten free pizza' ---
# Fetched 20 recipes for 'gluten free pizza'
# Saved 20 recipes to gluten_free_pizza_recipes.csv
#
# --- Starting 'gluten free pasta' ---
# Error for 'gluten free pasta': 429
# Fetched 0 recipes for 'gluten free pasta'
# Saved 0 recipes to gluten_free_pasta_recipes.csv
#
# --- Starting 'gluten free bread' ---
# Fetched 20 recipes for 'gluten free bread'
# Saved 20 recipes to gluten_free_bread_recipes.csv
#
# --- Starting 'keto' ---
# Error for 'keto': 429
# Fetched 0 recipes for 'keto'
# Saved 0 recipes to keto_recipes.csv
#
# --- Starting 'keto dinner' ---
# Fetched 20 recipes for 'keto dinner'
# Saved 20 recipes to keto_dinner_recipes.csv
#
# --- Starting 'keto salad' ---
# Error for 'keto salad': 429
# Fetched 0 recipes for 'keto salad'
# Saved 0 recipes to keto_salad_recipes.csv
#
# --- Starting 'keto chicken' ---
# Fetched 20 recipes for 'keto chicken'
# Saved 20 recipes to keto_chicken_recipes.csv
#
# --- Starting 'keto snacks' ---
# Error for 'keto snacks': 429
# Fetched 0 recipes for 'keto snacks'
# Saved 0 recipes to keto_snacks_recipes.csv
#
# --- Starting 'paleo' ---
# Fetched 20 recipes for 'paleo'
# Saved 20 recipes to paleo_recipes.csv
#
# --- Starting 'paleo soup' ---
# Error for 'paleo soup': 429
# Fetched 0 recipes for 'paleo soup'
# Saved 0 recipes to paleo_soup_recipes.csv
#
# --- Starting 'paleo diet' ---
# Fetched 20 recipes for 'paleo diet'
# Saved 20 recipes to paleo_diet_recipes.csv
#
# --- Starting 'paleo salad' ---
# Error for 'paleo salad': 429
# Fetched 0 recipes for 'paleo salad'
# Saved 0 recipes to paleo_salad_recipes.csv
#
# --- Starting 'low carb' ---
# Fetched 20 recipes for 'low carb'
# Saved 20 recipes to low_carb_recipes.csv
#
# --- Starting 'low carb dinner' ---
# Error for 'low carb dinner': 429
# Fetched 0 recipes for 'low carb dinner'
# Saved 0 recipes to low_carb_dinner_recipes.csv
#
# --- Starting 'low carb salad' ---
# Fetched 20 recipes for 'low carb salad'
# Saved 20 recipes to low_carb_salad_recipes.csv
#
# --- Starting 'low carb pizza' ---
# Error for 'low carb pizza': 429
# Fetched 0 recipes for 'low carb pizza'
# Saved 0 recipes to low_carb_pizza_recipes.csv
#
# --- Starting 'dairy free' ---
# Fetched 20 recipes for 'dairy free'
# Saved 20 recipes to dairy_free_recipes.csv
#
# --- Starting 'dairy free salad' ---
# Error for 'dairy free salad': 429
# Fetched 0 recipes for 'dairy free salad'
# Saved 0 recipes to dairy_free_salad_recipes.csv
#
# --- Starting 'dairy free cheese' ---
# Fetched 20 recipes for 'dairy free cheese'
# Saved 20 recipes to dairy_free_cheese_recipes.csv
#
# --- Starting 'dairy free cake' ---
# Error for 'dairy free cake': 429
# Fetched 0 recipes for 'dairy free cake'
# Saved 0 recipes to dairy_free_cake_recipes.csv
#
# --- Starting 'breakfast' ---
# Fetched 20 recipes for 'breakfast'
# Saved 20 recipes to breakfast_recipes.csv
#
# --- Starting 'breakfast bowl' ---
# Error for 'breakfast bowl': 429
# Fetched 0 recipes for 'breakfast bowl'
# Saved 0 recipes to breakfast_bowl_recipes.csv
#
# --- Starting 'breakfast smoothie' ---
# Fetched 20 recipes for 'breakfast smoothie'
# Saved 20 recipes to breakfast_smoothie_recipes.csv
#
# --- Starting 'breakfast burrito' ---
# Fetched 20 recipes for 'breakfast burrito'
# Saved 20 recipes to breakfast_burrito_recipes.csv
#
# --- Starting 'lunch' ---
# Error for 'lunch': 429
# Fetched 0 recipes for 'lunch'
# Saved 0 recipes to lunch_recipes.csv
#
# --- Starting 'lunch salad' ---
# Fetched 20 recipes for 'lunch salad'
# Saved 20 recipes to lunch_salad_recipes.csv
#
# --- Starting 'lunch bowl' ---
# Error for 'lunch bowl': 429
# Fetched 0 recipes for 'lunch bowl'
# Saved 0 recipes to lunch_bowl_recipes.csv
#
# --- Starting 'lunch sandwiches' ---
# Fetched 20 recipes for 'lunch sandwiches'
# Saved 20 recipes to lunch_sandwiches_recipes.csv
#
# --- Starting 'dinner' ---
# Error for 'dinner': 429
# Fetched 0 recipes for 'dinner'
# Saved 0 recipes to dinner_recipes.csv
#
# --- Starting 'dinner casserole' ---
# Fetched 20 recipes for 'dinner casserole'
# Saved 20 recipes to dinner_casserole_recipes.csv
#
# --- Starting 'dinner salad' ---
# Error for 'dinner salad': 429
# Fetched 0 recipes for 'dinner salad'
# Saved 0 recipes to dinner_salad_recipes.csv
#
# --- Starting 'dinner pizza' ---
# Fetched 20 recipes for 'dinner pizza'
# Saved 20 recipes to dinner_pizza_recipes.csv
#
# --- Starting 'snack' ---
# Error for 'snack': 429
# Fetched 0 recipes for 'snack'
# Saved 0 recipes to snack_recipes.csv
#
# --- Starting 'snack bars' ---
# Fetched 20 recipes for 'snack bars'
# Saved 20 recipes to snack_bars_recipes.csv
#
# --- Starting 'snack bites' ---
# Error for 'snack bites': 429
# Fetched 0 recipes for 'snack bites'
# Saved 0 recipes to snack_bites_recipes.csv
#
# --- Starting 'snack dips' ---
# Fetched 20 recipes for 'snack dips'
# Saved 20 recipes to snack_dips_recipes.csv
#
# --- Starting 'dessert' ---
# Error for 'dessert': 429
# Fetched 0 recipes for 'dessert'
# Saved 0 recipes to dessert_recipes.csv
#
# --- Starting 'dessert cake' ---
# Fetched 20 recipes for 'dessert cake'
# Saved 20 recipes to dessert_cake_recipes.csv
#
# --- Starting 'dessert cookies' ---
# Error for 'dessert cookies': 429
# Fetched 0 recipes for 'dessert cookies'
# Saved 0 recipes to dessert_cookies_recipes.csv
#
# --- Starting 'dessert pudding' ---
# Fetched 20 recipes for 'dessert pudding'
# Saved 20 recipes to dessert_pudding_recipes.csv
#
# --- Starting 'appetizer' ---
# Error for 'appetizer': 429
# Fetched 0 recipes for 'appetizer'
# Saved 0 recipes to appetizer_recipes.csv
#
# --- Starting 'appetizer salads' ---
# Fetched 20 recipes for 'appetizer salads'
# Saved 20 recipes to appetizer_salads_recipes.csv
#
# --- Starting 'appetizer dips' ---
# Error for 'appetizer dips': 429
# Fetched 0 recipes for 'appetizer dips'
# Saved 0 recipes to appetizer_dips_recipes.csv
#
# --- Starting 'appetizer recipes' ---
# Fetched 20 recipes for 'appetizer recipes'
# Saved 20 recipes to appetizer_recipes_recipes.csv
#
# --- Starting 'side dish' ---
# Error for 'side dish': 429
# Fetched 0 recipes for 'side dish'
# Saved 0 recipes to side_dish_recipes.csv
#
# --- Starting 'side salad' ---
# Fetched 20 recipes for 'side salad'
# Saved 20 recipes to side_salad_recipes.csv
#
# --- Starting 'side vegetables' ---
# Fetched 20 recipes for 'side vegetables'
# Saved 20 recipes to side_vegetables_recipes.csv
#
# --- Starting 'side casserole' ---
# Fetched 20 recipes for 'side casserole'
# Saved 20 recipes to side_casserole_recipes.csv
#
# --- Starting 'pasta' ---
# Fetched 20 recipes for 'pasta'
# Saved 20 recipes to pasta_recipes.csv
#
# --- Starting 'pasta salad' ---
# Fetched 20 recipes for 'pasta salad'
# Saved 20 recipes to pasta_salad_recipes.csv
#
# --- Starting 'pasta dishes' ---
# Error for 'pasta dishes': 429
# Fetched 0 recipes for 'pasta dishes'
# Saved 0 recipes to pasta_dishes_recipes.csv
#
# --- Starting 'pasta soup' ---
# Fetched 20 recipes for 'pasta soup'
# Saved 20 recipes to pasta_soup_recipes.csv
#
# --- Starting 'pizza' ---
# Error for 'pizza': 429
# Fetched 0 recipes for 'pizza'
# Saved 0 recipes to pizza_recipes.csv
#
# --- Starting 'pizza dough' ---
# Fetched 20 recipes for 'pizza dough'
# Saved 20 recipes to pizza_dough_recipes.csv
#
# --- Starting 'pizza toppings' ---
# Error for 'pizza toppings': 429
# Fetched 0 recipes for 'pizza toppings'
# Saved 0 recipes to pizza_toppings_recipes.csv
#
# --- Starting 'pizza recipes' ---
# Fetched 20 recipes for 'pizza recipes'
# Saved 20 recipes to pizza_recipes_recipes.csv
#
# --- Starting 'soup' ---
# Error for 'soup': 429
# Fetched 0 recipes for 'soup'
# Saved 0 recipes to soup_recipes.csv
#
# --- Starting 'soup recipes' ---
# Fetched 20 recipes for 'soup recipes'
# Saved 20 recipes to soup_recipes_recipes.csv
#
# --- Starting 'chicken soup' ---
# Error for 'chicken soup': 429
# Fetched 0 recipes for 'chicken soup'
# Saved 0 recipes to chicken_soup_recipes.csv
#
# --- Starting 'vegetable soup' ---
# Fetched 20 recipes for 'vegetable soup'
# Saved 20 recipes to vegetable_soup_recipes.csv
#
# --- Starting 'salad' ---
# Error for 'salad': 429
# Fetched 0 recipes for 'salad'
# Saved 0 recipes to salad_recipes.csv
#
# --- Starting 'green salad' ---
# Fetched 20 recipes for 'green salad'
# Saved 20 recipes to green_salad_recipes.csv
#
# --- Starting 'fruit salad' ---
# Error for 'fruit salad': 429
# Fetched 0 recipes for 'fruit salad'
# Saved 0 recipes to fruit_salad_recipes.csv
#
# --- Starting 'pasta salad' ---
# Fetched 20 recipes for 'pasta salad'
# Saved 20 recipes to pasta_salad_recipes.csv
#
# --- Starting 'curry' ---
# Error for 'curry': 429
# Fetched 0 recipes for 'curry'
# Saved 0 recipes to curry_recipes.csv
#
# --- Starting 'vegetable curry' ---
# Error for 'vegetable curry': 429
# Fetched 0 recipes for 'vegetable curry'
# Saved 0 recipes to vegetable_curry_recipes.csv
#
# --- Starting 'chicken curry' ---
# Fetched 20 recipes for 'chicken curry'
# Saved 20 recipes to chicken_curry_recipes.csv
#
# --- Starting 'beef curry' ---
# Error for 'beef curry': 429
# Fetched 0 recipes for 'beef curry'
# Saved 0 recipes to beef_curry_recipes.csv
#
# --- Starting 'stir fry' ---
# Fetched 20 recipes for 'stir fry'
# Saved 20 recipes to stir_fry_recipes.csv
#
# --- Starting 'chicken stir fry' ---
# Error for 'chicken stir fry': 429
# Fetched 0 recipes for 'chicken stir fry'
# Saved 0 recipes to chicken_stir_fry_recipes.csv
#
# --- Starting 'vegetable stir fry' ---
# Fetched 20 recipes for 'vegetable stir fry'
# Saved 20 recipes to vegetable_stir_fry_recipes.csv
#
# --- Starting 'shrimp stir fry' ---
# Error for 'shrimp stir fry': 429
# Fetched 0 recipes for 'shrimp stir fry'
# Saved 0 recipes to shrimp_stir_fry_recipes.csv
#
# --- Starting 'sandwich' ---
# Fetched 20 recipes for 'sandwich'
# Saved 20 recipes to sandwich_recipes.csv
#
# --- Starting 'vegan sandwich' ---
# Error for 'vegan sandwich': 429
# Fetched 0 recipes for 'vegan sandwich'
# Saved 0 recipes to vegan_sandwich_recipes.csv
#
# --- Starting 'chicken sandwich' ---
# Fetched 20 recipes for 'chicken sandwich'
# Saved 20 recipes to chicken_sandwich_recipes.csv
#
# --- Starting 'vegetarian sandwich' ---
# Error for 'vegetarian sandwich': 429
# Fetched 0 recipes for 'vegetarian sandwich'
# Saved 0 recipes to vegetarian_sandwich_recipes.csv
#
# All scraping tasks completed!

# %%
import zipfile
import os

# Create a zip file containing all *_recipes.csv files
with zipfile.ZipFile('edamam_csvs.zip', 'w') as zipf:
    for file in os.listdir():
        if file.endswith('_recipes.csv'):
            zipf.write(file)

print("All CSVs zipped to 'edamam_csvs.zip'")
# Out:
# All CSVs zipped to 'edamam_csvs.zip'

# %%
from google.colab import files
files.download('edamam_csvs.zip')
