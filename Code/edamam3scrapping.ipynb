# %%
pip install requests pandas
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.4.26)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import requests
import pandas as pd
import time

# === Your Edamam API credentials here ===
APP_ID = '59456ca4'
APP_KEY = 'ebeb4beaff17d1a14fcec62a904206a3'

# === EXTENDED SEARCH TERMS ===
SEARCH_TERMS = [
    # Ingredients
    'chicken drumsticks', 'chicken nuggets', 'roast chicken breast', 'chicken casserole',
    'beef burgers', 'beef ribs', 'beef brisket', 'steak', 'sirloin steak',
    'pork', 'pork chops', 'pork ribs', 'pork tenderloin', 'bacon',
    'turkey', 'ground turkey', 'turkey breast', 'roast turkey',
    'duck', 'duck breast', 'roast duck', 'confit duck',
    'lamb', 'lamb chops', 'lamb stew', 'ground lamb',
    'fish', 'cod', 'tuna', 'trout', 'tilapia',
    'crab', 'lobster', 'scallops', 'oysters', 'clams',
    'eggs', 'boiled eggs', 'scrambled eggs', 'omelet', 'poached eggs',
    'beans', 'black beans', 'kidney beans', 'chickpeas', 'white beans',
    'cheese', 'cheddar cheese', 'mozzarella', 'parmesan', 'goat cheese',
    'nuts', 'almonds', 'cashews', 'walnuts', 'pecans',
    'seeds', 'chia seeds', 'flax seeds', 'sunflower seeds', 'pumpkin seeds',

    # World Dishes
    'biryani', 'paella', 'ratatouille', 'shakshuka', 'moussaka',
    'bibimbap', 'pho', 'banh mi', 'laksa', 'tamales',
    'empanadas', 'ceviche', 'arepas', 'gnocchi', 'risotto',
    'crepes', 'coq au vin', 'bouillabaisse', 'cassoulet',
    'goulash', 'pierogi', 'sauerbraten', 'jollof rice', 'egusi soup',
    'poutine', 'chow mein', 'lo mein', 'hot pot', 'dim sum',
    'falafel', 'shawarma', 'tabbouleh', 'kofta', 'hummus bowl',

    # Cooking Methods
    'roasted vegetables', 'grilled meat', 'baked potatoes', 'boiled eggs',
    'fried chicken', 'steamed vegetables', 'poached fish', 'slow cooked beef',
    'air fryer recipes', 'instant pot recipes', 'one pot meals', 'sheet pan dinners',

    # Diets
    'whole30', 'diabetic friendly', 'heart healthy', 'low sodium', 'high protein',
    'low fat', 'high fiber', 'anti-inflammatory recipes', 'pcos diet',
    'renal diet', 'dash diet', 'fodmap recipes', 'low sugar dessert',

    # Occasions
    'holiday dinner', 'thanksgiving turkey', 'christmas cookies', 'easter brunch',
    'valentine’s dinner', 'birthday cake', 'summer bbq', 'picnic food',
    'meal prep', 'office lunch', 'kids lunch', 'school snacks',
    'family dinner', 'romantic dinner', 'weeknight dinner', 'lazy meals',

    # Breakfast
    'french toast', 'pancakes', 'waffles', 'granola', 'muffins',
    'breakfast sandwich', 'breakfast casserole', 'breakfast tacos', 'overnight oats',

    # Desserts
    'brownies', 'cheesecake', 'apple pie', 'banana bread', 'ice cream',
    'cupcakes', 'fudge', 'pudding recipes', 'lemon bars', 'fruit tarts',

    # Seasonal
    'summer salad', 'winter soup', 'fall stew', 'spring vegetables',
    'cold pasta salad', 'hot chili', 'light dinner', 'comfort food',

    # Beverages
    'green smoothie', 'protein shake', 'fruit smoothie', 'vegetable juice', 'detox drink',
    'mocktail recipes', 'iced tea', 'bubble tea', 'chai latte', 'cold brew coffee',

    # Grains & Bread
    'sourdough bread', 'cornbread', 'flatbread', 'naan bread', 'bagels',
    'rice dishes', 'wild rice', 'brown rice', 'couscous', 'bulgur',
    'barley soup', 'farro salad', 'millet recipes', 'amaranth bowl',

    # Trendy
    'avocado recipes', 'cauliflower rice', 'zoodles', 'stuffed peppers', 'buddha bowl',
    'poke bowl', 'cloud bread', 'chaffle recipes', 'cabbage soup', 'egg muffins'
]

# Settings
TOTAL_RECIPES_TARGET = 10000  # Can be increased or decreased
RECIPES_PER_TERM = TOTAL_RECIPES_TARGET // len(SEARCH_TERMS)
RECIPES_PER_REQUEST = 100
BASE_URL = 'https://api.edamam.com/api/recipes/v2'

# Function to fetch recipes
def fetch_recipes(query, total_recipes):
    all_recipes = []
    next_url = f"{BASE_URL}?type=public&q={query}&app_id={APP_ID}&app_key={APP_KEY}&random=true"

    fetched = 0
    request_count = 0
    requests_needed = (total_recipes + RECIPES_PER_REQUEST - 1) // RECIPES_PER_REQUEST

    while fetched < total_recipes:
        if request_count >= requests_needed:
            break

        response = requests.get(next_url)
        if response.status_code != 200:
            print(f"Error for '{query}': {response.status_code}")
            break

        data = response.json()
        hits = data.get('hits', [])
        if not hits:
            break

        for hit in hits:
            recipe = hit['recipe']
            all_recipes.append({
                'title': recipe.get('label', ''),
                'ingredients': '; '.join(recipe.get('ingredientLines', [])),
                'calories': recipe['totalNutrients'].get('ENERC_KCAL', {}).get('quantity', 0),
                'fat': recipe['totalNutrients'].get('FAT', {}).get('quantity', 0),
                'protein': recipe['totalNutrients'].get('PROCNT', {}).get('quantity', 0),
                'carbs': recipe['totalNutrients'].get('CHOCDF', {}).get('quantity', 0),
                'url': recipe.get('url', ''),
                'servings': recipe.get('yield', 1)
            })
            fetched += 1
            if fetched >= total_recipes:
                break

        next_link = data.get('_links', {}).get('next', {}).get('href')
        if not next_link:
            break
        next_url = next_link

        request_count += 1
        time.sleep(6)  # Respect API rate limits

    print(f"Fetched {fetched} recipes for '{query}'")
    return all_recipes

# Save to CSV
def save_to_csv(recipes, filename):
    df = pd.DataFrame(recipes)
    df.to_csv(filename, index=False)
    print(f"Saved {len(df)} recipes to {filename}")

# Main Script
if __name__ == "__main__":
    for term in SEARCH_TERMS:
        print(f"\n--- Starting '{term}' ---")
        data = fetch_recipes(term, RECIPES_PER_TERM)
        save_to_csv(data, f"{term.replace(' ', '_')}_recipes.csv")

    print("\nAll scraping tasks completed!")
# Out:
# --- Starting 'chicken drumsticks' ---
# Fetched 20 recipes for 'chicken drumsticks'
# Saved 20 recipes to chicken_drumsticks_recipes.csv
#
# --- Starting 'chicken nuggets' ---
# Fetched 20 recipes for 'chicken nuggets'
# Saved 20 recipes to chicken_nuggets_recipes.csv
#
# --- Starting 'roast chicken breast' ---
# Fetched 20 recipes for 'roast chicken breast'
# Saved 20 recipes to roast_chicken_breast_recipes.csv
#
# --- Starting 'chicken casserole' ---
# Fetched 20 recipes for 'chicken casserole'
# Saved 20 recipes to chicken_casserole_recipes.csv
#
# --- Starting 'beef burgers' ---
# Fetched 20 recipes for 'beef burgers'
# Saved 20 recipes to beef_burgers_recipes.csv
#
# --- Starting 'beef ribs' ---
# Fetched 20 recipes for 'beef ribs'
# Saved 20 recipes to beef_ribs_recipes.csv
#
# --- Starting 'beef brisket' ---
# Fetched 20 recipes for 'beef brisket'
# Saved 20 recipes to beef_brisket_recipes.csv
#
# --- Starting 'steak' ---
# Fetched 20 recipes for 'steak'
# Saved 20 recipes to steak_recipes.csv
#
# --- Starting 'sirloin steak' ---
# Fetched 20 recipes for 'sirloin steak'
# Saved 20 recipes to sirloin_steak_recipes.csv
#
# --- Starting 'pork' ---
# Fetched 20 recipes for 'pork'
# Saved 20 recipes to pork_recipes.csv
#
# --- Starting 'pork chops' ---
# Fetched 20 recipes for 'pork chops'
# Saved 20 recipes to pork_chops_recipes.csv
#
# --- Starting 'pork ribs' ---
# Fetched 20 recipes for 'pork ribs'
# Saved 20 recipes to pork_ribs_recipes.csv
#
# --- Starting 'pork tenderloin' ---
# Fetched 20 recipes for 'pork tenderloin'
# Saved 20 recipes to pork_tenderloin_recipes.csv
#
# --- Starting 'bacon' ---
# Fetched 20 recipes for 'bacon'
# Saved 20 recipes to bacon_recipes.csv
#
# --- Starting 'turkey' ---
# Fetched 20 recipes for 'turkey'
# Saved 20 recipes to turkey_recipes.csv
#
# --- Starting 'ground turkey' ---
# Fetched 20 recipes for 'ground turkey'
# Saved 20 recipes to ground_turkey_recipes.csv
#
# --- Starting 'turkey breast' ---
# Fetched 20 recipes for 'turkey breast'
# Saved 20 recipes to turkey_breast_recipes.csv
#
# --- Starting 'roast turkey' ---
# Fetched 20 recipes for 'roast turkey'
# Saved 20 recipes to roast_turkey_recipes.csv
#
# --- Starting 'duck' ---
# Fetched 20 recipes for 'duck'
# Saved 20 recipes to duck_recipes.csv
#
# --- Starting 'duck breast' ---
# Fetched 20 recipes for 'duck breast'
# Saved 20 recipes to duck_breast_recipes.csv
#
# --- Starting 'roast duck' ---
# Fetched 20 recipes for 'roast duck'
# Saved 20 recipes to roast_duck_recipes.csv
#
# --- Starting 'confit duck' ---
# Fetched 20 recipes for 'confit duck'
# Saved 20 recipes to confit_duck_recipes.csv
#
# --- Starting 'lamb' ---
# Fetched 20 recipes for 'lamb'
# Saved 20 recipes to lamb_recipes.csv
#
# --- Starting 'lamb chops' ---
# Fetched 20 recipes for 'lamb chops'
# Saved 20 recipes to lamb_chops_recipes.csv
#
# --- Starting 'lamb stew' ---
# Fetched 20 recipes for 'lamb stew'
# Saved 20 recipes to lamb_stew_recipes.csv
#
# --- Starting 'ground lamb' ---
# Fetched 20 recipes for 'ground lamb'
# Saved 20 recipes to ground_lamb_recipes.csv
#
# --- Starting 'fish' ---
# Fetched 20 recipes for 'fish'
# Saved 20 recipes to fish_recipes.csv
#
# --- Starting 'cod' ---
# Fetched 20 recipes for 'cod'
# Saved 20 recipes to cod_recipes.csv
#
# --- Starting 'tuna' ---
# Fetched 20 recipes for 'tuna'
# Saved 20 recipes to tuna_recipes.csv
#
# --- Starting 'trout' ---
# Fetched 20 recipes for 'trout'
# Saved 20 recipes to trout_recipes.csv
#
# --- Starting 'tilapia' ---
# Fetched 20 recipes for 'tilapia'
# Saved 20 recipes to tilapia_recipes.csv
#
# --- Starting 'crab' ---
# Fetched 20 recipes for 'crab'
# Saved 20 recipes to crab_recipes.csv
#
# --- Starting 'lobster' ---
# Fetched 20 recipes for 'lobster'
# Saved 20 recipes to lobster_recipes.csv
#
# --- Starting 'scallops' ---
# Fetched 20 recipes for 'scallops'
# Saved 20 recipes to scallops_recipes.csv
#
# --- Starting 'oysters' ---
# Fetched 20 recipes for 'oysters'
# Saved 20 recipes to oysters_recipes.csv
#
# --- Starting 'clams' ---
# Fetched 20 recipes for 'clams'
# Saved 20 recipes to clams_recipes.csv
#
# --- Starting 'eggs' ---
# Fetched 20 recipes for 'eggs'
# Saved 20 recipes to eggs_recipes.csv
#
# --- Starting 'boiled eggs' ---
# Fetched 20 recipes for 'boiled eggs'
# Saved 20 recipes to boiled_eggs_recipes.csv
#
# --- Starting 'scrambled eggs' ---
# Fetched 20 recipes for 'scrambled eggs'
# Saved 20 recipes to scrambled_eggs_recipes.csv
#
# --- Starting 'omelet' ---
# Fetched 20 recipes for 'omelet'
# Saved 20 recipes to omelet_recipes.csv
#
# --- Starting 'poached eggs' ---
# Fetched 20 recipes for 'poached eggs'
# Saved 20 recipes to poached_eggs_recipes.csv
#
# --- Starting 'beans' ---
# Fetched 20 recipes for 'beans'
# Saved 20 recipes to beans_recipes.csv
#
# --- Starting 'black beans' ---
# Fetched 20 recipes for 'black beans'
# Saved 20 recipes to black_beans_recipes.csv
#
# --- Starting 'kidney beans' ---
# Fetched 20 recipes for 'kidney beans'
# Saved 20 recipes to kidney_beans_recipes.csv
#
# --- Starting 'chickpeas' ---
# Fetched 20 recipes for 'chickpeas'
# Saved 20 recipes to chickpeas_recipes.csv
#
# --- Starting 'white beans' ---
# Fetched 20 recipes for 'white beans'
# Saved 20 recipes to white_beans_recipes.csv
#
# --- Starting 'cheese' ---
# Fetched 20 recipes for 'cheese'
# Saved 20 recipes to cheese_recipes.csv
#
# --- Starting 'cheddar cheese' ---
# Fetched 20 recipes for 'cheddar cheese'
# Saved 20 recipes to cheddar_cheese_recipes.csv
#
# --- Starting 'mozzarella' ---
# Fetched 20 recipes for 'mozzarella'
# Saved 20 recipes to mozzarella_recipes.csv
#
# --- Starting 'parmesan' ---
# Fetched 20 recipes for 'parmesan'
# Saved 20 recipes to parmesan_recipes.csv
#
# --- Starting 'goat cheese' ---
# Fetched 20 recipes for 'goat cheese'
# Saved 20 recipes to goat_cheese_recipes.csv
#
# --- Starting 'nuts' ---
# Fetched 20 recipes for 'nuts'
# Saved 20 recipes to nuts_recipes.csv
#
# --- Starting 'almonds' ---
# Fetched 20 recipes for 'almonds'
# Saved 20 recipes to almonds_recipes.csv
#
# --- Starting 'cashews' ---
# Fetched 20 recipes for 'cashews'
# Saved 20 recipes to cashews_recipes.csv
#
# --- Starting 'walnuts' ---
# Fetched 20 recipes for 'walnuts'
# Saved 20 recipes to walnuts_recipes.csv
#
# --- Starting 'pecans' ---
# Fetched 20 recipes for 'pecans'
# Saved 20 recipes to pecans_recipes.csv
#
# --- Starting 'seeds' ---
# Fetched 20 recipes for 'seeds'
# Saved 20 recipes to seeds_recipes.csv
#
# --- Starting 'chia seeds' ---
# Fetched 20 recipes for 'chia seeds'
# Saved 20 recipes to chia_seeds_recipes.csv
#
# --- Starting 'flax seeds' ---
# Fetched 20 recipes for 'flax seeds'
# Saved 20 recipes to flax_seeds_recipes.csv
#
# --- Starting 'sunflower seeds' ---
# Fetched 20 recipes for 'sunflower seeds'
# Saved 20 recipes to sunflower_seeds_recipes.csv
#
# --- Starting 'pumpkin seeds' ---
# Fetched 20 recipes for 'pumpkin seeds'
# Saved 20 recipes to pumpkin_seeds_recipes.csv
#
# --- Starting 'biryani' ---
# Fetched 20 recipes for 'biryani'
# Saved 20 recipes to biryani_recipes.csv
#
# --- Starting 'paella' ---
# Fetched 20 recipes for 'paella'
# Saved 20 recipes to paella_recipes.csv
#
# --- Starting 'ratatouille' ---
# Fetched 20 recipes for 'ratatouille'
# Saved 20 recipes to ratatouille_recipes.csv
#
# --- Starting 'shakshuka' ---
# Fetched 20 recipes for 'shakshuka'
# Saved 20 recipes to shakshuka_recipes.csv
#
# --- Starting 'moussaka' ---
# Fetched 20 recipes for 'moussaka'
# Saved 20 recipes to moussaka_recipes.csv
#
# --- Starting 'bibimbap' ---
# Fetched 20 recipes for 'bibimbap'
# Saved 20 recipes to bibimbap_recipes.csv
#
# --- Starting 'pho' ---
# Fetched 20 recipes for 'pho'
# Saved 20 recipes to pho_recipes.csv
#
# --- Starting 'banh mi' ---
# Fetched 20 recipes for 'banh mi'
# Saved 20 recipes to banh_mi_recipes.csv
#
# --- Starting 'laksa' ---
# Fetched 20 recipes for 'laksa'
# Saved 20 recipes to laksa_recipes.csv
#
# --- Starting 'tamales' ---
# Fetched 20 recipes for 'tamales'
# Saved 20 recipes to tamales_recipes.csv
#
# --- Starting 'empanadas' ---
# Fetched 20 recipes for 'empanadas'
# Saved 20 recipes to empanadas_recipes.csv
#
# --- Starting 'ceviche' ---
# Fetched 20 recipes for 'ceviche'
# Saved 20 recipes to ceviche_recipes.csv
#
# --- Starting 'arepas' ---
# Fetched 20 recipes for 'arepas'
# Saved 20 recipes to arepas_recipes.csv
#
# --- Starting 'gnocchi' ---
# Fetched 20 recipes for 'gnocchi'
# Saved 20 recipes to gnocchi_recipes.csv
#
# --- Starting 'risotto' ---
# Fetched 20 recipes for 'risotto'
# Saved 20 recipes to risotto_recipes.csv
#
# --- Starting 'crepes' ---
# Fetched 20 recipes for 'crepes'
# Saved 20 recipes to crepes_recipes.csv
#
# --- Starting 'coq au vin' ---
# Fetched 20 recipes for 'coq au vin'
# Saved 20 recipes to coq_au_vin_recipes.csv
#
# --- Starting 'bouillabaisse' ---
# Fetched 20 recipes for 'bouillabaisse'
# Saved 20 recipes to bouillabaisse_recipes.csv
#
# --- Starting 'cassoulet' ---
# Fetched 20 recipes for 'cassoulet'
# Saved 20 recipes to cassoulet_recipes.csv
#
# --- Starting 'goulash' ---
# Fetched 20 recipes for 'goulash'
# Saved 20 recipes to goulash_recipes.csv
#
# --- Starting 'pierogi' ---
# Fetched 20 recipes for 'pierogi'
# Saved 20 recipes to pierogi_recipes.csv
#
# --- Starting 'sauerbraten' ---
# Fetched 20 recipes for 'sauerbraten'
# Saved 20 recipes to sauerbraten_recipes.csv
#
# --- Starting 'jollof rice' ---
# Fetched 20 recipes for 'jollof rice'
# Saved 20 recipes to jollof_rice_recipes.csv
#
# --- Starting 'egusi soup' ---
# Fetched 9 recipes for 'egusi soup'
# Saved 9 recipes to egusi_soup_recipes.csv
#
# --- Starting 'poutine' ---
# Fetched 20 recipes for 'poutine'
# Saved 20 recipes to poutine_recipes.csv
#
# --- Starting 'chow mein' ---
# Fetched 20 recipes for 'chow mein'
# Saved 20 recipes to chow_mein_recipes.csv
#
# --- Starting 'lo mein' ---
# Fetched 20 recipes for 'lo mein'
# Saved 20 recipes to lo_mein_recipes.csv
#
# --- Starting 'hot pot' ---
# Fetched 20 recipes for 'hot pot'
# Saved 20 recipes to hot_pot_recipes.csv
#
# --- Starting 'dim sum' ---
# Fetched 20 recipes for 'dim sum'
# Saved 20 recipes to dim_sum_recipes.csv
#
# --- Starting 'falafel' ---
# Fetched 20 recipes for 'falafel'
# Saved 20 recipes to falafel_recipes.csv
#
# --- Starting 'shawarma' ---
# Fetched 20 recipes for 'shawarma'
# Saved 20 recipes to shawarma_recipes.csv
#
# --- Starting 'tabbouleh' ---
# Fetched 20 recipes for 'tabbouleh'
# Saved 20 recipes to tabbouleh_recipes.csv
#
# --- Starting 'kofta' ---
# Fetched 20 recipes for 'kofta'
# Saved 20 recipes to kofta_recipes.csv
#
# --- Starting 'hummus bowl' ---
# Fetched 20 recipes for 'hummus bowl'
# Saved 20 recipes to hummus_bowl_recipes.csv
#
# --- Starting 'roasted vegetables' ---
# Fetched 20 recipes for 'roasted vegetables'
# Saved 20 recipes to roasted_vegetables_recipes.csv
#
# --- Starting 'grilled meat' ---
# Fetched 20 recipes for 'grilled meat'
# Saved 20 recipes to grilled_meat_recipes.csv
#
# --- Starting 'baked potatoes' ---
# Fetched 20 recipes for 'baked potatoes'
# Saved 20 recipes to baked_potatoes_recipes.csv
#
# --- Starting 'boiled eggs' ---
# Fetched 20 recipes for 'boiled eggs'
# Saved 20 recipes to boiled_eggs_recipes.csv
#
# --- Starting 'fried chicken' ---
# Fetched 20 recipes for 'fried chicken'
# Saved 20 recipes to fried_chicken_recipes.csv
#
# --- Starting 'steamed vegetables' ---
# Fetched 20 recipes for 'steamed vegetables'
# Saved 20 recipes to steamed_vegetables_recipes.csv
#
# --- Starting 'poached fish' ---
# Fetched 20 recipes for 'poached fish'
# Saved 20 recipes to poached_fish_recipes.csv
#
# --- Starting 'slow cooked beef' ---
# Fetched 20 recipes for 'slow cooked beef'
# Saved 20 recipes to slow_cooked_beef_recipes.csv
#
# --- Starting 'air fryer recipes' ---
# Fetched 20 recipes for 'air fryer recipes'
# Saved 20 recipes to air_fryer_recipes_recipes.csv
#
# --- Starting 'instant pot recipes' ---
# Fetched 20 recipes for 'instant pot recipes'
# Saved 20 recipes to instant_pot_recipes_recipes.csv
#
# --- Starting 'one pot meals' ---
# Fetched 20 recipes for 'one pot meals'
# Saved 20 recipes to one_pot_meals_recipes.csv
#
# --- Starting 'sheet pan dinners' ---
# Fetched 20 recipes for 'sheet pan dinners'
# Saved 20 recipes to sheet_pan_dinners_recipes.csv
#
# --- Starting 'whole30' ---
# Fetched 20 recipes for 'whole30'
# Saved 20 recipes to whole30_recipes.csv
#
# --- Starting 'diabetic friendly' ---
# Fetched 20 recipes for 'diabetic friendly'
# Saved 20 recipes to diabetic_friendly_recipes.csv
#
# --- Starting 'heart healthy' ---
# Fetched 20 recipes for 'heart healthy'
# Saved 20 recipes to heart_healthy_recipes.csv
#
# --- Starting 'low sodium' ---
# Fetched 20 recipes for 'low sodium'
# Saved 20 recipes to low_sodium_recipes.csv
#
# --- Starting 'high protein' ---
# Fetched 20 recipes for 'high protein'
# Saved 20 recipes to high_protein_recipes.csv
#
# --- Starting 'low fat' ---
# Fetched 20 recipes for 'low fat'
# Saved 20 recipes to low_fat_recipes.csv
#
# --- Starting 'high fiber' ---
# Fetched 20 recipes for 'high fiber'
# Saved 20 recipes to high_fiber_recipes.csv
#
# --- Starting 'anti-inflammatory recipes' ---
# Fetched 20 recipes for 'anti-inflammatory recipes'
# Saved 20 recipes to anti-inflammatory_recipes_recipes.csv
#
# --- Starting 'pcos diet' ---
# Fetched 0 recipes for 'pcos diet'
# Saved 0 recipes to pcos_diet_recipes.csv
#
# --- Starting 'renal diet' ---
# Fetched 20 recipes for 'renal diet'
# Saved 20 recipes to renal_diet_recipes.csv
#
# --- Starting 'dash diet' ---
# Fetched 20 recipes for 'dash diet'
# Saved 20 recipes to dash_diet_recipes.csv
#
# --- Starting 'fodmap recipes' ---
# Fetched 20 recipes for 'fodmap recipes'
# Saved 20 recipes to fodmap_recipes_recipes.csv
#
# --- Starting 'low sugar dessert' ---
# Fetched 20 recipes for 'low sugar dessert'
# Saved 20 recipes to low_sugar_dessert_recipes.csv
#
# --- Starting 'holiday dinner' ---
# Fetched 20 recipes for 'holiday dinner'
# Saved 20 recipes to holiday_dinner_recipes.csv
#
# --- Starting 'thanksgiving turkey' ---
# Fetched 20 recipes for 'thanksgiving turkey'
# Saved 20 recipes to thanksgiving_turkey_recipes.csv
#
# --- Starting 'christmas cookies' ---
# Fetched 20 recipes for 'christmas cookies'
# Saved 20 recipes to christmas_cookies_recipes.csv
#
# --- Starting 'easter brunch' ---
# Fetched 20 recipes for 'easter brunch'
# Saved 20 recipes to easter_brunch_recipes.csv
#
# --- Starting 'valentine’s dinner' ---
# Fetched 20 recipes for 'valentine’s dinner'
# Saved 20 recipes to valentine’s_dinner_recipes.csv
#
# --- Starting 'birthday cake' ---
# Fetched 20 recipes for 'birthday cake'
# Saved 20 recipes to birthday_cake_recipes.csv
#
# --- Starting 'summer bbq' ---
# Fetched 20 recipes for 'summer bbq'
# Saved 20 recipes to summer_bbq_recipes.csv
#
# --- Starting 'picnic food' ---
# Fetched 20 recipes for 'picnic food'
# Saved 20 recipes to picnic_food_recipes.csv
#
# --- Starting 'meal prep' ---
# Fetched 20 recipes for 'meal prep'
# Saved 20 recipes to meal_prep_recipes.csv
#
# --- Starting 'office lunch' ---
# Fetched 20 recipes for 'office lunch'
# Saved 20 recipes to office_lunch_recipes.csv
#
# --- Starting 'kids lunch' ---
# Fetched 20 recipes for 'kids lunch'
# Saved 20 recipes to kids_lunch_recipes.csv
#
# --- Starting 'school snacks' ---
# Fetched 20 recipes for 'school snacks'
# Saved 20 recipes to school_snacks_recipes.csv
#
# --- Starting 'family dinner' ---
# Fetched 20 recipes for 'family dinner'
# Saved 20 recipes to family_dinner_recipes.csv
#
# --- Starting 'romantic dinner' ---
# Fetched 20 recipes for 'romantic dinner'
# Saved 20 recipes to romantic_dinner_recipes.csv
#
# --- Starting 'weeknight dinner' ---
# Fetched 20 recipes for 'weeknight dinner'
# Saved 20 recipes to weeknight_dinner_recipes.csv
#
# --- Starting 'lazy meals' ---
# Error for 'lazy meals': 429
# Fetched 0 recipes for 'lazy meals'
# Saved 0 recipes to lazy_meals_recipes.csv
#
# --- Starting 'french toast' ---
# Fetched 20 recipes for 'french toast'
# Saved 20 recipes to french_toast_recipes.csv
#
# --- Starting 'pancakes' ---
# Error for 'pancakes': 429
# Fetched 0 recipes for 'pancakes'
# Saved 0 recipes to pancakes_recipes.csv
#
# --- Starting 'waffles' ---
# Fetched 20 recipes for 'waffles'
# Saved 20 recipes to waffles_recipes.csv
#
# --- Starting 'granola' ---
# Error for 'granola': 429
# Fetched 0 recipes for 'granola'
# Saved 0 recipes to granola_recipes.csv
#
# --- Starting 'muffins' ---
# Fetched 20 recipes for 'muffins'
# Saved 20 recipes to muffins_recipes.csv
#
# --- Starting 'breakfast sandwich' ---
# Error for 'breakfast sandwich': 429
# Fetched 0 recipes for 'breakfast sandwich'
# Saved 0 recipes to breakfast_sandwich_recipes.csv
#
# --- Starting 'breakfast casserole' ---
# Error for 'breakfast casserole': 429
# Fetched 0 recipes for 'breakfast casserole'
# Saved 0 recipes to breakfast_casserole_recipes.csv
#
# --- Starting 'breakfast tacos' ---
# Fetched 20 recipes for 'breakfast tacos'
# Saved 20 recipes to breakfast_tacos_recipes.csv
#
# --- Starting 'overnight oats' ---
# Error for 'overnight oats': 429
# Fetched 0 recipes for 'overnight oats'
# Saved 0 recipes to overnight_oats_recipes.csv
#
# --- Starting 'brownies' ---
# Fetched 20 recipes for 'brownies'
# Saved 20 recipes to brownies_recipes.csv
#
# --- Starting 'cheesecake' ---
# Error for 'cheesecake': 429
# Fetched 0 recipes for 'cheesecake'
# Saved 0 recipes to cheesecake_recipes.csv
#
# --- Starting 'apple pie' ---
# Fetched 20 recipes for 'apple pie'
# Saved 20 recipes to apple_pie_recipes.csv
#
# --- Starting 'banana bread' ---
# Error for 'banana bread': 429
# Fetched 0 recipes for 'banana bread'
# Saved 0 recipes to banana_bread_recipes.csv
#
# --- Starting 'ice cream' ---
# Fetched 20 recipes for 'ice cream'
# Saved 20 recipes to ice_cream_recipes.csv
#
# --- Starting 'cupcakes' ---
# Error for 'cupcakes': 429
# Fetched 0 recipes for 'cupcakes'
# Saved 0 recipes to cupcakes_recipes.csv
#
# --- Starting 'fudge' ---
# Fetched 20 recipes for 'fudge'
# Saved 20 recipes to fudge_recipes.csv
#
# --- Starting 'pudding recipes' ---
# Error for 'pudding recipes': 429
# Fetched 0 recipes for 'pudding recipes'
# Saved 0 recipes to pudding_recipes_recipes.csv
#
# --- Starting 'lemon bars' ---
# Fetched 20 recipes for 'lemon bars'
# Saved 20 recipes to lemon_bars_recipes.csv
#
# --- Starting 'fruit tarts' ---
# Fetched 20 recipes for 'fruit tarts'
# Saved 20 recipes to fruit_tarts_recipes.csv
#
# --- Starting 'summer salad' ---
# Error for 'summer salad': 429
# Fetched 0 recipes for 'summer salad'
# Saved 0 recipes to summer_salad_recipes.csv
#
# --- Starting 'winter soup' ---
# Fetched 20 recipes for 'winter soup'
# Saved 20 recipes to winter_soup_recipes.csv
#
# --- Starting 'fall stew' ---
# Error for 'fall stew': 429
# Fetched 0 recipes for 'fall stew'
# Saved 0 recipes to fall_stew_recipes.csv
#
# --- Starting 'spring vegetables' ---
# Fetched 20 recipes for 'spring vegetables'
# Saved 20 recipes to spring_vegetables_recipes.csv
#
# --- Starting 'cold pasta salad' ---
# Error for 'cold pasta salad': 429
# Fetched 0 recipes for 'cold pasta salad'
# Saved 0 recipes to cold_pasta_salad_recipes.csv
#
# --- Starting 'hot chili' ---
# Fetched 20 recipes for 'hot chili'
# Saved 20 recipes to hot_chili_recipes.csv
#
# --- Starting 'light dinner' ---
# Error for 'light dinner': 429
# Fetched 0 recipes for 'light dinner'
# Saved 0 recipes to light_dinner_recipes.csv
#
# --- Starting 'comfort food' ---
# Fetched 20 recipes for 'comfort food'
# Saved 20 recipes to comfort_food_recipes.csv
#
# --- Starting 'green smoothie' ---
# Error for 'green smoothie': 429
# Fetched 0 recipes for 'green smoothie'
# Saved 0 recipes to green_smoothie_recipes.csv
#
# --- Starting 'protein shake' ---
# Fetched 20 recipes for 'protein shake'
# Saved 20 recipes to protein_shake_recipes.csv
#
# --- Starting 'fruit smoothie' ---
# Fetched 20 recipes for 'fruit smoothie'
# Saved 20 recipes to fruit_smoothie_recipes.csv
#
# --- Starting 'vegetable juice' ---
# Fetched 20 recipes for 'vegetable juice'
# Saved 20 recipes to vegetable_juice_recipes.csv
#
# --- Starting 'detox drink' ---
# Fetched 20 recipes for 'detox drink'
# Saved 20 recipes to detox_drink_recipes.csv
#
# --- Starting 'mocktail recipes' ---
# Fetched 20 recipes for 'mocktail recipes'
# Saved 20 recipes to mocktail_recipes_recipes.csv
#
# --- Starting 'iced tea' ---
# Fetched 20 recipes for 'iced tea'
# Saved 20 recipes to iced_tea_recipes.csv
#
# --- Starting 'bubble tea' ---
# Fetched 20 recipes for 'bubble tea'
# Saved 20 recipes to bubble_tea_recipes.csv
#
# --- Starting 'chai latte' ---
# Fetched 20 recipes for 'chai latte'
# Saved 20 recipes to chai_latte_recipes.csv
#
# --- Starting 'cold brew coffee' ---
# Fetched 20 recipes for 'cold brew coffee'
# Saved 20 recipes to cold_brew_coffee_recipes.csv
#
# --- Starting 'sourdough bread' ---
# Fetched 20 recipes for 'sourdough bread'
# Saved 20 recipes to sourdough_bread_recipes.csv
#
# --- Starting 'cornbread' ---
# Fetched 20 recipes for 'cornbread'
# Saved 20 recipes to cornbread_recipes.csv
#
# --- Starting 'flatbread' ---
# Fetched 20 recipes for 'flatbread'
# Saved 20 recipes to flatbread_recipes.csv
#
# --- Starting 'naan bread' ---
# Fetched 20 recipes for 'naan bread'
# Saved 20 recipes to naan_bread_recipes.csv
#
# --- Starting 'bagels' ---
# Fetched 20 recipes for 'bagels'
# Saved 20 recipes to bagels_recipes.csv
#
# --- Starting 'rice dishes' ---
# Fetched 20 recipes for 'rice dishes'
# Saved 20 recipes to rice_dishes_recipes.csv
#
# --- Starting 'wild rice' ---
# Fetched 20 recipes for 'wild rice'
# Saved 20 recipes to wild_rice_recipes.csv
#
# --- Starting 'brown rice' ---
# Fetched 20 recipes for 'brown rice'
# Saved 20 recipes to brown_rice_recipes.csv
#
# --- Starting 'couscous' ---
# Fetched 20 recipes for 'couscous'
# Saved 20 recipes to couscous_recipes.csv
#
# --- Starting 'bulgur' ---
# Fetched 20 recipes for 'bulgur'
# Saved 20 recipes to bulgur_recipes.csv
#
# --- Starting 'barley soup' ---
# Fetched 20 recipes for 'barley soup'
# Saved 20 recipes to barley_soup_recipes.csv
#
# --- Starting 'farro salad' ---
# Fetched 20 recipes for 'farro salad'
# Saved 20 recipes to farro_salad_recipes.csv
#
# --- Starting 'millet recipes' ---
# Fetched 20 recipes for 'millet recipes'
# Saved 20 recipes to millet_recipes_recipes.csv
#
# --- Starting 'amaranth bowl' ---
# Fetched 10 recipes for 'amaranth bowl'
# Saved 10 recipes to amaranth_bowl_recipes.csv
#
# --- Starting 'avocado recipes' ---
# Fetched 20 recipes for 'avocado recipes'
# Saved 20 recipes to avocado_recipes_recipes.csv
#
# --- Starting 'cauliflower rice' ---
# Fetched 20 recipes for 'cauliflower rice'
# Saved 20 recipes to cauliflower_rice_recipes.csv
#
# --- Starting 'zoodles' ---
# Fetched 20 recipes for 'zoodles'
# Saved 20 recipes to zoodles_recipes.csv
#
# --- Starting 'stuffed peppers' ---
# Fetched 20 recipes for 'stuffed peppers'
# Saved 20 recipes to stuffed_peppers_recipes.csv
#
# --- Starting 'buddha bowl' ---
# Fetched 20 recipes for 'buddha bowl'
# Saved 20 recipes to buddha_bowl_recipes.csv
#
# --- Starting 'poke bowl' ---
# Fetched 20 recipes for 'poke bowl'
# Saved 20 recipes to poke_bowl_recipes.csv
#
# --- Starting 'cloud bread' ---
# Fetched 20 recipes for 'cloud bread'
# Saved 20 recipes to cloud_bread_recipes.csv
#
# --- Starting 'chaffle recipes' ---
# Fetched 2 recipes for 'chaffle recipes'
# Saved 2 recipes to chaffle_recipes_recipes.csv
#
# --- Starting 'cabbage soup' ---
# Fetched 20 recipes for 'cabbage soup'
# Saved 20 recipes to cabbage_soup_recipes.csv
#
# --- Starting 'egg muffins' ---
# Fetched 20 recipes for 'egg muffins'
# Saved 20 recipes to egg_muffins_recipes.csv
#
# All scraping tasks completed!

# %%
import pandas as pd
import glob
import os

# Path where your CSV files are stored (adjust if needed)
csv_folder = '.'  # current directory

# Pattern matching all recipe CSV files
csv_files = glob.glob(os.path.join(csv_folder, '*_recipes.csv'))

# List to hold each dataframe
dfs = []

for file in csv_files:
    try:
        df = pd.read_csv(file)
        # Check if the DataFrame is not empty before appending
        if not df.empty:
            dfs.append(df)
        else:
            print(f"Skipping empty file: {file}")
    except pd.errors.EmptyDataError:
        # Handle the specific error if a file is truly empty or only has headers
        print(f"Skipping empty or header-only file: {file}")
    except Exception as e:
        # Catch any other potential errors during reading
        print(f"Error reading file {file}: {e}")


# Check if there are any dataframes to concatenate
if dfs:
    # Combine all dataframes into one
    combined_df = pd.concat(dfs, ignore_index=True)

    # Optional: remove duplicates if any
    combined_df.drop_duplicates(inplace=True)

    # Save the combined dataframe
    combined_df.to_csv('combined_recipes.csv', index=False)

    print(f"Combined {len(csv_files)} files into 'combined_recipes.csv' with {len(combined_df)} rows (skipped empty/invalid files).")
else:
    print("No valid dataframes found to combine.")
# Out:
# Skipping empty or header-only file: ./cupcakes_recipes.csv
# Skipping empty or header-only file: ./breakfast_sandwich_recipes.csv
# Skipping empty or header-only file: ./light_dinner_recipes.csv
# Skipping empty or header-only file: ./cold_pasta_salad_recipes.csv
# Skipping empty or header-only file: ./banana_bread_recipes.csv
# Skipping empty or header-only file: ./breakfast_casserole_recipes.csv
# Skipping empty or header-only file: ./pudding_recipes_recipes.csv
# Skipping empty or header-only file: ./summer_salad_recipes.csv
# Skipping empty or header-only file: ./fall_stew_recipes.csv
# Skipping empty or header-only file: ./pancakes_recipes.csv
# Skipping empty or header-only file: ./pcos_diet_recipes.csv
# Skipping empty or header-only file: ./overnight_oats_recipes.csv
# Skipping empty or header-only file: ./green_smoothie_recipes.csv
# Skipping empty or header-only file: ./cheesecake_recipes.csv
# Skipping empty or header-only file: ./lazy_meals_recipes.csv
# Skipping empty or header-only file: ./granola_recipes.csv
# Combined 196 files into 'combined_recipes.csv' with 3551 rows (skipped empty/invalid files).
